# %%
from FaceNetEvaluator import FaceNetEvaluator
from FaceNetModel2 import FaceNetModel2
from TrainTestSplitter import TrainTestSplitter
from DataPreparation import DataPreparation
import os

original_data_dir = "../dataset_images"
dataset_dir = "celeb7"  # Path to your dataset folder
sample_class_number = 7

data_preparation = DataPreparation(original_data_dir, dataset_dir, sample_class_number)
selected_classes = data_preparation.prepare_data()

# Example Usage:
splitter = TrainTestSplitter(dataset_dir)
splitter.create_train_test_split()

# Assuming you already have the FaceNetModel instance and the model is loaded
model = FaceNetModel2("../inception-v3")

# Create embeddings for the training data
model.create_embeddings_for_personality(dataset_dir)


# Step 3: Evaluate the model using the embeddings and test folder
evaluator = FaceNetEvaluator(dataset_dir=dataset_dir, model=model)
evaluator.evaluate()
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# #### Now trying a model with Augmentation

# %%
from FaceNetEvaluator import FaceNetEvaluator
from FaceNetModelAug import FaceNetModelAug
from TrainTestSplitter import TrainTestSplitter
from DataPreparation import DataPreparation
import os

original_data_dir = "../dataset_images"
dataset_dir = "celeb7Aug"  # Path to your dataset folder
sample_class_number = 7

data_preparation = DataPreparation(original_data_dir, dataset_dir, sample_class_number)
selected_classes = data_preparation.prepare_data()

# Example Usage:
splitter = TrainTestSplitter(dataset_dir)
splitter.create_train_test_split()

# Assuming you already have the FaceNetModel instance and the model is loaded
model = FaceNetModel2("../inception-v3")

# Create embeddings for the training data
model.create_embeddings_for_personality(dataset_dir)


# Step 3: Evaluate the model using the embeddings and test folder
evaluator = FaceNetEvaluator(dataset_dir=dataset_dir, model=model)
evaluator.evaluate()
# Out:
# Moved one image to test and the rest to train for  Chris Hemsworth.
# Moved one image to test and the rest to train for  Christina Ricci.
# Moved one image to test and the rest to train for  Gemma Whelan.
# Moved one image to test and the rest to train for  Judy Dench.
# Moved one image to test and the rest to train for  Maya Rudolph.
# Moved one image to test and the rest to train for  Samara Weaving.
# Moved one image to test and the rest to train for  Shawn Mendes.
# InceptionResNetV1 model loaded successfully!
# Accuracy: 100.00%

# %%
from SimilarityCalculator import SimilarityCalculator
from FaceNetModelAug import FaceNetModelAug
import pandas as pd

# Similarity calculation
face_net_model = FaceNetModelAug()
embeddings_dir = "celeb7Aug/embeddings"
similarity_calculator = SimilarityCalculator(embeddings_dir)
test_image_path = "../test_image/ricci.jpg"
similar_personality = similarity_calculator.calculate_similarity(test_image_path, face_net_model)

df = pd.DataFrame(similar_personality)
print(f"Most similar personality: {similar_personality[0][0]} with similarity score: {similar_personality[0][1]}")
display(df)
# Out:
# InceptionResNetV1 model loaded successfully!
# Most similar personality:  Christina Ricci with similarity score: 0.786702573299408
#                   0         1
# 0   Christina Ricci  0.786703
# 1      Maya Rudolph  0.707855
# 2    Samara Weaving  0.671881
# 3      Gemma Whelan  0.632681
# 4        Judy Dench  0.600277
# 5      Shawn Mendes  0.576107
# 6   Chris Hemsworth  0.362149

# %% [markdown]
# After augmentation we can see that the accuracy has gone considerably high

# %%
from FaceNetEvaluator import FaceNetEvaluator
from FaceNetModelAug import FaceNetModelAug
from TrainTestSplitter import TrainTestSplitter
from DataPreparation import DataPreparation
import os

original_data_dir = "../dataset_images"
dataset_dir = "../datasets/celeb50Augmented"  # Path to your dataset folder
sample_class_number = 50

data_preparation = DataPreparation(original_data_dir, dataset_dir, sample_class_number)
selected_classes = data_preparation.prepare_data()

# Example Usage:
splitter = TrainTestSplitter(dataset_dir)
splitter.create_train_test_split()

# Assuming you already have the FaceNetModel instance and the model is loaded
model = FaceNetModel2("../inception-v3")

# Create embeddings for the training data
model.create_embeddings_for_personality(dataset_dir)


# Step 3: Evaluate the model using the embeddings and test folder
evaluator = FaceNetEvaluator(dataset_dir=dataset_dir, model=model)
evaluator.evaluate()
# Out:
# Moved one image to test and the rest to train for  Aaron Eckhart.
# Moved one image to test and the rest to train for  Adam Levine.
# Moved one image to test and the rest to train for  Amy Poehler.
# Moved one image to test and the rest to train for  Angelina Jolie.
# Moved one image to test and the rest to train for  AnnaSophia Robb.
# Moved one image to test and the rest to train for  Anthony Joshua.
# Moved one image to test and the rest to train for  Antonio Banderas.
# Moved one image to test and the rest to train for  Bella Thorne.
# Moved one image to test and the rest to train for  Christopher Plummer.
# Moved one image to test and the rest to train for  Clive Owen.
# Moved one image to test and the rest to train for  Cobie Smulders.
# Moved one image to test and the rest to train for  Connie Britton.
# Moved one image to test and the rest to train for  Dakota Fanning.
# Moved one image to test and the rest to train for  Dolly Parton.
# ...

# %%
from SimilarityCalculator import SimilarityCalculator
from FaceNetModelAug import FaceNetModelAug
import pandas as pd

# Similarity calculation
face_net_model = FaceNetModelAug()
embeddings_dir = "../datasets/celeb50Augmented/embeddings"
similarity_calculator = SimilarityCalculator(embeddings_dir)
test_image_path = "../test_image/regina.jpg"
similar_personality = similarity_calculator.calculate_similarity(test_image_path, face_net_model)

df = pd.DataFrame(similar_personality)
print(f"Most similar personality: {similar_personality[0][0]} with similarity score: {similar_personality[0][1]}")
display(df)
# Out:
# InceptionResNetV1 model loaded successfully!
# Most similar personality:  Regina Hall with similarity score: 0.9218270778656006
#                          0         1
# 0              Regina Hall  0.921827
# 1           Angelina Jolie  0.909181
# 2           Cobie Smulders  0.905431
# 3                a Seydoux  0.902871
# 4    Sarah Michelle Gellar  0.901746
# 5        Hayden Panettiere  0.901717
# 6                Lucy Hale  0.893435
# 7              Naomi Watts  0.892500
# 8           Dakota Fanning  0.889116
# 9            Michelle Yeoh  0.888843
# 10       Jennifer Lawrence  0.887819
# 11     Katherine Waterston  0.885770
# 12    Sarah Jessica Parker  0.885417
# 13            Kristen Bell  0.883229
# 14             Amy Poehler  0.883007
# 15            Bella Thorne  0.877000
# 16            Gina Gershon  0.876730
# 17          Phoebe Dynevor  0.875978
# 18              Lisa Bonet  0.869366
# 19          Connie Britton  0.865149
# 20         AnnaSophia Robb  0.864202
# ...

# %%
from FaceNetModelAug import FaceNetModelAug
from FaceNetEvaluator import FaceNetEvaluator
# Step 3: Evaluate the model using the embeddings and test folder
face_net_model = FaceNetModelAug()
dataset_dir = "../datasets/celeb50Augmented"
evaluator = FaceNetEvaluator(dataset_dir=dataset_dir, model=face_net_model)
evaluator.evaluate()
# Out:
# InceptionResNetV1 model loaded successfully!
# Predicted:  Norman Reedus Actual:  Aaron Eckhart
# Predicted:  Anthony Joshua Actual:  Adam Levine
# Predicted:  Naomi Watts Actual:  Angelina Jolie
# Predicted:  Katherine Waterston Actual:  AnnaSophia Robb
# Predicted:  Jared Leto Actual:  Antonio Banderas
# Predicted:  Sarah Michelle Gellar Actual:  Bella Thorne
# Predicted:  Clive Owen Actual:  Christopher Plummer
# Predicted:  Angelina Jolie Actual:  Cobie Smulders
# Predicted:  Jennifer Lawrence Actual:  Hayden Panettiere
# Predicted:  Michael Pena Actual:  Jared Leto
# Predicted:  Gwen Stefani Actual:  Jennifer Lawrence
# Predicted:  Scott Speedman Actual:  Jeremy Renner
# Predicted:  KJ Apa Actual:  Josh Hutcherson
# Predicted:  Jared Leto Actual:  Justin Hartley
# Predicted:  Michelle Yeoh Actual:  Katherine Waterston
# Predicted:  AnnaSophia Robb Actual:  Kristen Bell
# Predicted:  Katherine Waterston Actual:  Lucy Hale
# Predicted:  Michael Pena Actual:  Luke Evans
# ...

# %%
# Assuming you already have the FaceNetModel instance and the model is loaded
from FaceNetModelAugMax import FaceNetModelAugMax
from FaceNetEvaluator import FaceNetEvaluator

model = FaceNetModelAugMax("../inception-v3")
# Create embeddings for the training data
dataset_dir = "../datasets/celeb50Augmented"
model.create_embeddings_for_personality(dataset_dir)
# Step 3: Evaluate the model using the embeddings and test folder
evaluator = FaceNetEvaluator(dataset_dir=dataset_dir, model=model)
evaluator.evaluate()
# Out:
# InceptionResNetV1 model loaded successfully!
# Predicted:  Matt Bomer Actual:  Aaron Eckhart
# Predicted:  Matt Bomer Actual:  Adam Levine
# Predicted:  Bella Thorne Actual:  Angelina Jolie
# Predicted:  Katherine Waterston Actual:  AnnaSophia Robb
# Predicted:  Luke Evans Actual:  Anthony Joshua
# Predicted:  Matt Bomer Actual:  Antonio Banderas
# Predicted:  Matt Bomer Actual:  Christopher Plummer
# Predicted:  Matt Bomer Actual:  Clive Owen
# Predicted:  Katherine Waterston Actual:  Cobie Smulders
# Predicted:  Bella Thorne Actual:  Dakota Fanning
# Predicted:  Matt Bomer Actual:  Giancarlo Esposito
# Predicted:  Bella Thorne Actual:  Gina Gershon
# Predicted:  Bella Thorne Actual:  Gwen Stefani
# Predicted:  Bella Thorne Actual:  Hayden Panettiere
# Predicted:  Matt Bomer Actual:  Jaden Smith
# Predicted:  Matt Bomer Actual:  Jared Leto
# Predicted:  Bella Thorne Actual:  Jennifer Lawrence
# Predicted:  Matt Bomer Actual:  Jeremy Renner
# ...

# %%
# Assuming you already have the FaceNetModel instance and the model is loaded
from FaceNetAdvancedEvaluator import FaceNetAdvancedEvaluator
from FaceNetModelAdvanced import FaceNetModelAdvanced

model = FaceNetModelAdvanced("../inception-v3")
# Create embeddings for the training data
dataset_dir = "../datasets/celeb7-Advanced"
model.create_embeddings_for_personality(dataset_dir, False)

# %%
# Step 3: Evaluate the model using the embeddings and test folder
from FaceNetAdvancedEvaluator import FaceNetAdvancedEvaluator
from FaceNetModelAdvanced import FaceNetModelAdvanced

model = FaceNetModelAdvanced("../inception-v3")
dataset_dir = "../datasets/celeb7-Advanced"
evaluator = FaceNetAdvancedEvaluator(dataset_dir=dataset_dir, model=model)
evaluator.evaluate()
# Out:
# InceptionResNetV1 model loaded successfully!
# Total Remaining : 7
# Binary Search till 1
# Shape of all embeddings of the person (18, 1, 1001)
# Shape of all embeddings of the person for each (1, 1001)
# Shape of test embedding (1, 1001)
# Shape of all embeddings of the person (18, 1, 1001)
# Shape of all embeddings of the person for each (1, 1001)
# Shape of test embedding (1, 1001)
# Shape of all embeddings of the person (18, 1, 1001)
# Shape of all embeddings of the person for each (1, 1001)
# Shape of test embedding (1, 1001)
# Shape of all embeddings of the person (18, 1, 1001)
# Shape of all embeddings of the person for each (1, 1001)
# Shape of test embedding (1, 1001)
# Shape of all embeddings of the person (19, 1, 1001)
# Shape of all embeddings of the person for each (1, 1001)
# Shape of test embedding (1, 1001)
# Shape of all embeddings of the person (19, 1, 1001)
# Shape of all embeddings of the person for each (1, 1001)
# Shape of test embedding (1, 1001)
# ...

# %%
from SimilarityCalculatorAdvancedCorrected2 import SimilarityCalculatorAdvancedCorrected2
from FaceNetModelAdvanced import FaceNetModelAdvanced
import pandas as pd

# Similarity calculation
face_net_model = FaceNetModelAdvanced()
embeddings_dir = "../datasets/celeb7-Advanced/embeddings"
similarity_calculator = SimilarityCalculatorAdvancedCorrected2(embeddings_dir)
test_image_path = "../test_image/mayarudolph.jpg"
similar_personality_by_average = similarity_calculator.calculate_similarity(test_image_path, face_net_model)

df = pd.DataFrame(similar_personality_by_average)
print(f"Most similar personality Avergae based: {similar_personality_by_average[0][0]} with similarity score: {similar_personality_by_average[0][1]}")
display(df)
# Out:
# InceptionResNetV1 model loaded successfully!
# ../test_image/mayarudolph.jpg
# Total Remaining : 7
# Binary Search till 1
# Round 10 scores: [(' Gemma Whelan', np.float32(0.71808404)), (' Maya Rudolph', np.float32(0.70134205)), (' Christina Ricci', np.float32(0.6879795)), (' Shawn Mendes', np.float32(0.6422309)), (' Samara Weaving', np.float32(0.641503)), (' Judy Dench', np.float32(0.6235146)), (' Chris Hemsworth', np.float32(0.6114922))]
# Round 10 scores: [(' Maya Rudolph', np.float32(0.49113417)), (' Judy Dench', np.float32(0.46437234)), (' Gemma Whelan', np.float32(0.46188343)), (' Christina Ricci', np.float32(0.44954145)), (' Samara Weaving', np.float32(0.43304443)), (' Shawn Mendes', np.float32(0.41209817)), (' Chris Hemsworth', np.float32(0.36513054))]
# ...

# %% [markdown]
# #### Comparing with Augmented model

# %%
from SimilarityCalculator import SimilarityCalculator
from FaceNetModelAug import FaceNetModelAug
import pandas as pd

#Training on the same dataset celeb7
# Assuming you already have the FaceNetModel instance and the model is loaded
from FaceNetModelAug import FaceNetModelAug

model = FaceNetModelAug("../inception-v3")
# Create embeddings for the training data
dataset_dir = "../datasets/celeb7-Advanced"
model.create_embeddings_for_personality(dataset_dir)

# %%
from SimilarityCalculator import SimilarityCalculator
from FaceNetModelAug import FaceNetModelAug
import pandas as pd
# Similarity calculation
face_net_model = FaceNetModelAug()
embeddings_dir = "../datasets/celeb7-Advanced/embeddings"
similarity_calculator = SimilarityCalculator(embeddings_dir)
test_image_path = "../test_image/chris.jpg"
similar_personality = similarity_calculator.calculate_similarity(test_image_path, face_net_model)

df = pd.DataFrame(similar_personality)
print(f"Most similar personality: {similar_personality[0][0]} with similarity score: {similar_personality[0][1]}")
display(df)
# Out:
# InceptionResNetV1 model loaded successfully!
# Most similar personality:  Chris Hemsworth with similarity score: 0.8330737948417664
#                   0         1
# 0   Chris Hemsworth  0.833074
# 1      Shawn Mendes  0.762192
# 2        Judy Dench  0.635296
# 3      Gemma Whelan  0.568120
# 4      Maya Rudolph  0.549645
# 5   Christina Ricci  0.510177
# 6    Samara Weaving  0.476087

# %%
from SimilarityCalculatorAdvancedCorrected2 import SimilarityCalculatorAdvancedCorrected2
from SimilarityCalculator import SimilarityCalculator

from FaceNetModelAdvanced import FaceNetModelAdvanced
import pandas as pd

# Similarity calculation
face_net_model = FaceNetModelAdvanced()
embeddings_dir = "../datasets/celeb50Augmented/embeddings-mean"
similarity_calculator = SimilarityCalculatorAdvancedCorrected2(embeddings_dir)
test_image_path = "../test_image/sophie.jpg"
similar_personality_avg= similarity_calculator.calculate_similarity(test_image_path, face_net_model)

df1 = pd.DataFrame(similar_personality_avg)
print(f"Most similar personality: {similar_personality_avg[0][0]} with similarity score: {similar_personality_avg[0][1]}")

similarity_calculatorBasic = SimilarityCalculator(embeddings_dir)
similar_personality_basic = similarity_calculatorBasic.calculate_similarity(test_image_path, face_net_model)

df2 = pd.DataFrame(similar_personality_basic)
print(f"Most similar personality: {similar_personality_basic[0][0]} with similarity score: {similar_personality_basic[0][1]}")

df1['rank1'] = df1.index
df2['rank2'] = df2.index

merged_df = pd.merge(df1, df2, on=0, suffixes=('_df1', '_df2'))
merged_df = merged_df[[0, 'rank1', 'rank2', '1_df1', '1_df2']]
display(merged_df)
print("*"*40)
print("Basic")
display(df2.head(5))
print("*"*40)
print("Advanced")
display(df1.head(5))
# Out:
# InceptionResNetV1 model loaded successfully!
# ../test_image/sophie.jpg
# Total Remaining : 50
# Binary Search till 5
# ...
