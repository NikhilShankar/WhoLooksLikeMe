# %% [markdown]
# #### **Training**

# %%
# Assuming you already have the FaceNetModel instance and the model is loaded
from FaceNetAdvancedEvaluator import FaceNetAdvancedEvaluator
from FaceNetModelAdvanced import FaceNetModelAdvanced

dataset_dir = "../datasets/celeb10AdvancedWithProfilePhotosOnly"
model = FaceNetModelAdvanced("../inception-v3")
# Create embeddings for the training data
model.create_embeddings_for_personality(dataset_dir, False)
# Out:
# InceptionResNetV1 model loaded successfully!
# Augmentation : {should_augment} with augmentated image count : {augmentation_count}
# {' Chloe Sevigny': array([[[-0.49779648, -0.36647692, -0.06999174, ..., -0.5890678 ,
#            2.8381476 ,  2.5136242 ]],
#
#         [[-0.6295236 ,  0.3651697 , -0.6124026 , ..., -1.7259517 ,
#            0.46210113,  0.5233348 ]],
#
#         [[-0.2981075 ,  2.4724474 , -0.5554073 , ..., -0.02407771,
#            0.8821944 ,  0.35465932]],
#
#         ...,
#
#         [[-0.2981075 ,  2.4724474 , -0.5554073 , ..., -0.02407771,
#            0.8821944 ,  0.35465932]],
#
#         [[-0.48704088,  0.5221953 , -0.48735887, ..., -1.9741876 ,
#            0.7834122 ,  0.4686033 ]],
#
#         [[-0.2908851 , -0.46183097, -0.12818071, ..., -0.770356  ,
#            2.530776  ,  1.7179607 ]]], dtype=float32),
#  ' David Harbour': array([[[-0.22519177,  2.5168219 ,  0.3114613 , ..., -0.19150144,
#            0.12428916,  0.13410738]],
#
#         [[-0.4663292 ,  4.2685113 ,  0.32392898, ...,  0.8709186 ,
#            1.5486672 ,  0.3066784 ]],
#
#         [[-0.5753322 ,  4.3981256 , -0.17077243, ...,  0.82277673,
#            1.7351438 , -0.9220476 ]],
#
#         [[-0.36460853,  7.0497146 , -0.0961735 , ...,  0.475447  ,
#            0.96924126,  0.06432292]],
#
#         [[-0.27031356,  1.4790773 , -0.38401693, ..., -0.58450985,
#            0.89612985, -0.68854296]],
#
#         [[-0.32773206,  4.1412416 , -0.69400734, ...,  0.98621756,
#            1.1189361 , -0.14616941]]], dtype=float32),
#  ' Emma Chamberlain': array([[[-0.36860362,  0.07687376, -0.7253443 , ..., -1.1041961 ,
#            1.0043306 ,  0.672574  ]],
#
#         [[-0.43774343,  1.1121496 , -0.76061964, ..., -0.63530785,
#            0.45200762,  1.6954199 ]],
#
#         [[-0.34043604,  0.01138839, -0.9348472 , ..., -0.47959507,
#           -1.0899117 ,  0.91718626]],
#
#         [[-0.46124464,  0.48582047, -0.24663113, ..., -1.2016001 ,
#            0.2871113 ,  0.87552136]],
#
#         [[-0.33358157, -0.11127315, -1.316463  , ..., -1.4868689 ,
#            1.2556025 ,  1.4849086 ]],
#
#         [[-0.41581026,  0.04251753, -0.52577007, ..., -1.276613  ,
#           -0.7376646 ,  0.79288954]]], dtype=float32),
#  ' Florence Pugh': array([[[-0.27059138,  0.17609788, -0.27544126, ..., -0.8247205 ,
#            0.5749986 ,  1.5358324 ]],
#
#         [[-0.7011486 ,  1.3598486 ,  0.11421862, ..., -0.08711472,
#            3.5489326 ,  0.3887717 ]],
#
#         [[-0.55667186,  0.27820623, -0.57347596, ..., -1.1252918 ,
#           -0.32158086,  1.9199806 ]],
#
#         ...,
#
#         [[-0.8067406 ,  0.57284963, -0.68683326, ..., -1.2971871 ,
#            0.90139306,  1.1557627 ]],
#
#         [[-0.36029166,  0.6842414 , -0.55561507, ..., -0.36385155,
#            0.21497199,  0.62417537]],
#
#         [[-0.47790462,  1.9488488 , -0.3160691 , ...,  0.4276595 ,
#            3.3051255 ,  0.241536  ]]], dtype=float32),
#  ' Lily Rabe': array([[[-0.39800093,  0.47802305, -0.14895701, ..., -0.9415565 ,
#            0.8258387 ,  0.5119038 ]],
#
#         [[-0.60212755,  0.88165855, -0.20589848, ..., -0.5553366 ,
#            0.90835464,  0.5406808 ]],
#
#         [[-0.19473982,  0.6736385 , -0.97317815, ..., -0.3945767 ,
#            0.1451546 ,  1.3074731 ]],
#
#         ...,
#
#         [[-0.33657724,  0.25263804, -0.40372202, ..., -0.5268977 ,
#            0.7661443 ,  1.0576812 ]],
#
#         [[-0.37574738,  0.01329842, -0.6801743 , ..., -0.7447019 ,
#            0.70046544,  0.74938285]],
#
#         [[-0.56761557,  1.9010187 , -0.7807348 , ..., -0.7014505 ,
#            1.5195892 ,  0.4074577 ]]], dtype=float32),
#  ' Penelope Cruz': array([[[-0.10901445, -0.63157636, -0.5080571 , ..., -1.2243636 ,
#            0.36036292,  1.0254626 ]],
#
#         [[-0.48938698, -0.6079736 , -0.8522317 , ..., -0.60348296,
#            0.57012355,  2.2775064 ]],
#
#         [[-0.503924  ,  0.8462696 , -1.1711657 , ..., -0.6817765 ,
#            0.9793235 ,  0.77839506]],
#
#         ...,
#
#         [[-0.3699909 ,  0.78668773, -0.2115458 , ..., -1.3756788 ,
#            0.96852744,  0.04823928]],
#
#         [[-0.5462622 ,  0.76725364, -0.06241956, ..., -0.5146108 ,
#            0.4502385 ,  0.69326824]],
#
#         [[-0.46066663,  0.7727726 , -0.9415252 , ..., -1.0970888 ,
#            1.1973022 ,  0.45405114]]], dtype=float32),
#  ' Sam Rockwell': array([[[-0.6116384 ,  4.188642  ,  0.32012543, ..., -0.45726678,
#            0.4150662 ,  0.36969817]],
#
#         [[-0.43120253,  4.0612197 ,  0.04783466, ..., -0.29785347,
#            1.5485246 , -0.61573005]],
#
#         [[-0.26779464,  5.2771444 ,  0.0450395 , ..., -0.57009745,
#            0.46983686,  0.36113822]],
#
#         ...,
#
#         [[-0.62370783,  5.455554  ,  0.48572508, ...,  0.45571834,
#            1.6375754 ,  0.01488099]],
#
#         [[-0.34228373,  5.941135  ,  0.4345427 , ...,  0.76314336,
#            0.8543831 ,  0.15727578]],
#
#         [[-0.32226664,  1.6826286 , -0.37105188, ..., -0.66318834,
#            0.7432879 ,  1.3468809 ]]], dtype=float32),
#  ' Tom Hollander': array([[[-0.3744879 ,  2.7100806 ,  0.37860665, ..., -0.21878764,
#            0.9714209 , -1.1976801 ]],
#
#         [[-0.4955243 ,  4.0571513 ,  0.1070523 , ..., -0.4432072 ,
#            0.5971124 , -0.08882983]],
#
#         [[-0.40339264,  2.7953582 ,  0.5416285 , ..., -0.41758457,
#            0.6146873 , -0.9291502 ]],
#
#         ...,
#
#         [[-0.06433636,  2.416066  , -0.5188781 , ...,  0.06680721,
#            0.9608244 ,  0.03139161]],
#
#         [[ 0.18759978,  1.3466007 ,  1.0574684 , ..., -0.12067524,
#            2.8761744 , -1.1688123 ]],
#
#         [[-0.31520084,  2.6394517 , -0.25160578, ...,  0.4042998 ,
#            0.50456476, -0.19161771]]], dtype=float32),
#  ' Vincent Cassel': array([[[-0.17432201,  3.2104623 ,  0.26616618, ..., -0.21528241,
#            0.4952831 , -0.18328206]],
#
#         [[-0.41461462,  0.8537071 , -0.21878873, ..., -0.12071112,
#            0.7760601 , -0.42532188]],
#
#         [[-0.5182121 ,  1.9716955 , -0.06210122, ..., -0.8877083 ,
#            0.8375262 , -0.15790708]],
#
#         ...,
#
#         [[-0.3437625 ,  3.9272027 , -0.5647925 , ..., -0.02608854,
#            0.85071456,  0.41891313]],
#
#         [[-0.47021252,  1.9713022 , -0.22440791, ..., -0.85676825,
#            0.31485233,  0.75550663]],
#
#         [[-0.44203082,  5.927275  , -0.16360655, ...,  0.20328009,
#            1.0629445 ,  0.40207934]]], dtype=float32),
#  ' Zoe Kravitz': array([[[-0.44585308, -0.00574379, -0.12146747, ..., -1.3432195 ,
#           -0.19355455,  1.7451888 ]],
#
#         [[-0.41497493,  1.9308509 , -0.41647395, ..., -0.20988369,
#            0.2868017 ,  0.3933869 ]],
#
#         [[-0.4650234 ,  1.2766162 , -0.40802416, ..., -0.7009342 ,
#            0.4730995 ,  0.09482983]],
#
#         ...,
#
#         [[-0.49549437,  0.3156942 , -0.40838873, ..., -0.39813733,
#            0.8848442 ,  0.32079118]],
#
#         [[-0.3511464 ,  1.1655589 , -0.25347024, ...,  0.35381705,
#            1.2283186 ,  0.9332613 ]],
#
#         [[-0.31332582,  0.4188931 , -0.13820267, ..., -1.0655973 ,
#            0.33617178,  0.29467613]]], dtype=float32)}

# %% [markdown]
# #### **Evaluation**

# %%
# Step 3: Evaluate the model using the embeddings and test folder
from FaceNetAdvancedEvaluatorCorrected import FaceNetAdvancedEvaluatorCorrected
from FaceNetModelAdvanced import FaceNetModelAdvanced

dataset_dir = "../datasets/celeb10AdvancedWithProfilePhotosOnly"
model = FaceNetModelAdvanced("../inception-v3")
evaluator = FaceNetAdvancedEvaluatorCorrected(dataset_dir=dataset_dir, model=model)
evaluator.evaluate()
# Out:
# InceptionResNetV1 model loaded successfully!
# ../datasets/celeb10AdvancedWithProfilePhotosOnly\test\ Chloe Sevigny\image_2538_ Chloe Sevigny.jpg
# Total Remaining : 10
# Binary Search till 2
# Average scores: {' Chloe Sevigny': np.float32(0.7017678), ' David Harbour': np.float32(0.53663176), ' Emma Chamberlain': np.float32(0.7641633), ' Florence Pugh': np.float32(0.76845425), ' Lily Rabe': np.float32(0.778761), ' Penelope Cruz': np.float32(0.73690003), ' Sam Rockwell': np.float32(0.5570303), ' Tom Hollander': np.float32(0.49258232), ' Vincent Cassel': np.float32(0.48988858), ' Zoe Kravitz': np.float32(0.7490374)}
# Total scores: {' Chloe Sevigny': 52, ' David Harbour': 31, ' Emma Chamberlain': 82, ' Florence Pugh': 83, ' Lily Rabe': 94, ' Penelope Cruz': 63, ' Sam Rockwell': 39, ' Tom Hollander': 15, ' Vincent Cassel': 15, ' Zoe Kravitz': 76}
# ../datasets/celeb10AdvancedWithProfilePhotosOnly\test\ David Harbour\image_3695_ David Harbour.jpg
# Total Remaining : 10
# Binary Search till 2
# Average scores: {' Chloe Sevigny': np.float32(0.5465841), ' David Harbour': np.float32(0.7558822), ' Emma Chamberlain': np.float32(0.55099046), ' Florence Pugh': np.float32(0.54888356), ' Lily Rabe': np.float32(0.48397732), ' Penelope Cruz': np.float32(0.56161577), ' Sam Rockwell': np.float32(0.7624103), ' Tom Hollander': np.float32(0.77262396), ' Vincent Cassel': np.float32(0.783646), ' Zoe Kravitz': np.float32(0.65188926)}
# Total scores: {' Chloe Sevigny': 31, ' David Harbour': 80, ' Emma Chamberlain': 31, ' Florence Pugh': 33, ' Lily Rabe': 10, ' Penelope Cruz': 45, ' Sam Rockwell': 81, ' Tom Hollander': 86, ' Vincent Cassel': 93, ' Zoe Kravitz': 60}
# ../datasets/celeb10AdvancedWithProfilePhotosOnly\test\ Emma Chamberlain\image_4951_ Emma Chamberlain.jpg
# Total Remaining : 10
# Binary Search till 2
# Average scores: {' Chloe Sevigny': np.float32(0.669854), ' David Harbour': np.float32(0.5763172), ' Emma Chamberlain': np.float32(0.84098566), ' Florence Pugh': np.float32(0.73349327), ' Lily Rabe': np.float32(0.7180086), ' Penelope Cruz': np.float32(0.74212295), ' Sam Rockwell': np.float32(0.5861939), ' Tom Hollander': np.float32(0.5304125), ' Vincent Cassel': np.float32(0.5258088), ' Zoe Kravitz': np.float32(0.71466523)}
# Total scores: {' Chloe Sevigny': 49, ' David Harbour': 35, ' Emma Chamberlain': 100, ' Florence Pugh': 77, ' Lily Rabe': 70, ' Penelope Cruz': 85, ' Sam Rockwell': 35, ' Tom Hollander': 16, ' Vincent Cassel': 15, ' Zoe Kravitz': 68}
# ../datasets/celeb10AdvancedWithProfilePhotosOnly\test\ Florence Pugh\image_5377_ Florence Pugh.jpg
# Total Remaining : 10
# Binary Search till 2
# Average scores: {' Chloe Sevigny': np.float32(0.6944947), ' David Harbour': np.float32(0.5355445), ' Emma Chamberlain': np.float32(0.66589797), ' Florence Pugh': np.float32(0.70270175), ' Lily Rabe': np.float32(0.69848514), ' Penelope Cruz': np.float32(0.6896012), ' Sam Rockwell': np.float32(0.57332164), ' Tom Hollander': np.float32(0.51128066), ' Vincent Cassel': np.float32(0.55956733), ' Zoe Kravitz': np.float32(0.6799898)}
# Total scores: {' Chloe Sevigny': 80, ' David Harbour': 22, ' Emma Chamberlain': 55, ' Florence Pugh': 88, ' Lily Rabe': 83, ' Penelope Cruz': 76, ' Sam Rockwell': 34, ' Tom Hollander': 11, ' Vincent Cassel': 33, ' Zoe Kravitz': 68}
# ../datasets/celeb10AdvancedWithProfilePhotosOnly\test\ Lily Rabe\image_11172_ Lily Rabe.jpg
# Total Remaining : 10
# Binary Search till 2
# Average scores: {' Chloe Sevigny': np.float32(0.7496011), ' David Harbour': np.float32(0.5729195), ' Emma Chamberlain': np.float32(0.70993596), ' Florence Pugh': np.float32(0.74612844), ' Lily Rabe': np.float32(0.8009429), ' Penelope Cruz': np.float32(0.73831975), ' Sam Rockwell': np.float32(0.61449486), ' Tom Hollander': np.float32(0.5645752), ' Vincent Cassel': np.float32(0.60974735), ' Zoe Kravitz': np.float32(0.70659816)}
# Total scores: {' Chloe Sevigny': 83, ' David Harbour': 17, ' Emma Chamberlain': 60, ' Florence Pugh': 78, ' Lily Rabe': 99, ' Penelope Cruz': 72, ' Sam Rockwell': 35, ' Tom Hollander': 15, ' Vincent Cassel': 35, ' Zoe Kravitz': 56}
# ../datasets/celeb10AdvancedWithProfilePhotosOnly\test\ Penelope Cruz\image_14255_ Penelope Cruz.jpg
# Total Remaining : 10
# Binary Search till 2
# Average scores: {' Chloe Sevigny': np.float32(0.76549447), ' David Harbour': np.float32(0.5445323), ' Emma Chamberlain': np.float32(0.7684039), ' Florence Pugh': np.float32(0.7859316), ' Lily Rabe': np.float32(0.8020681), ' Penelope Cruz': np.float32(0.8109852), ' Sam Rockwell': np.float32(0.57686186), ' Tom Hollander': np.float32(0.5201873), ' Vincent Cassel': np.float32(0.52210605), ' Zoe Kravitz': np.float32(0.7648952)}
# Total scores: {' Chloe Sevigny': 61, ' David Harbour': 30, ' Emma Chamberlain': 64, ' Florence Pugh': 78, ' Lily Rabe': 88, ' Penelope Cruz': 95, ' Sam Rockwell': 36, ' Tom Hollander': 18, ' Vincent Cassel': 16, ' Zoe Kravitz': 64}
# ../datasets/celeb10AdvancedWithProfilePhotosOnly\test\ Sam Rockwell\image_15588_ Sam Rockwell.jpg
# Total Remaining : 10
# Binary Search till 2
# Average scores: {' Chloe Sevigny': np.float32(0.5747157), ' David Harbour': np.float32(0.7782757), ' Emma Chamberlain': np.float32(0.5329439), ' Florence Pugh': np.float32(0.5798052), ' Lily Rabe': np.float32(0.53371704), ' Penelope Cruz': np.float32(0.58716214), ' Sam Rockwell': np.float32(0.8044103), ' Tom Hollander': np.float32(0.7603814), ' Vincent Cassel': np.float32(0.76907235), ' Zoe Kravitz': np.float32(0.6548933)}
# Total scores: {' Chloe Sevigny': 37, ' David Harbour': 84, ' Emma Chamberlain': 16, ' Florence Pugh': 38, ' Lily Rabe': 16, ' Penelope Cruz': 43, ' Sam Rockwell': 94, ' Tom Hollander': 78, ' Vincent Cassel': 83, ' Zoe Kravitz': 61}
# ../datasets/celeb10AdvancedWithProfilePhotosOnly\test\ Tom Hollander\image_17246_ Tom Hollander.jpg
# Total Remaining : 10
# Binary Search till 2
# Average scores: {' Chloe Sevigny': np.float32(0.49666938), ' David Harbour': np.float32(0.80813265), ' Emma Chamberlain': np.float32(0.4893776), ' Florence Pugh': np.float32(0.52960545), ' Lily Rabe': np.float32(0.44288874), ' Penelope Cruz': np.float32(0.5540433), ' Sam Rockwell': np.float32(0.6903515), ' Tom Hollander': np.float32(0.78667736), ' Vincent Cassel': np.float32(0.7808231), ' Zoe Kravitz': np.float32(0.61271554)}
# Total scores: {' Chloe Sevigny': 26, ' David Harbour': 95, ' Emma Chamberlain': 24, ' Florence Pugh': 41, ' Lily Rabe': 10, ' Penelope Cruz': 49, ' Sam Rockwell': 70, ' Tom Hollander': 89, ' Vincent Cassel': 86, ' Zoe Kravitz': 60}
# ../datasets/celeb10AdvancedWithProfilePhotosOnly\test\ Vincent Cassel\image_17589_ Vincent Cassel.jpg
# Total Remaining : 10
# Binary Search till 2
# Average scores: {' Chloe Sevigny': np.float32(0.52796626), ' David Harbour': np.float32(0.6916305), ' Emma Chamberlain': np.float32(0.5052884), ' Florence Pugh': np.float32(0.5687541), ' Lily Rabe': np.float32(0.49377698), ' Penelope Cruz': np.float32(0.5499269), ' Sam Rockwell': np.float32(0.67509454), ' Tom Hollander': np.float32(0.690337), ' Vincent Cassel': np.float32(0.66125405), ' Zoe Kravitz': np.float32(0.55608726)}
# Total scores: {' Chloe Sevigny': 28, ' David Harbour': 92, ' Emma Chamberlain': 23, ' Florence Pugh': 55, ' Lily Rabe': 15, ' Penelope Cruz': 41, ' Sam Rockwell': 84, ' Tom Hollander': 87, ' Vincent Cassel': 77, ' Zoe Kravitz': 48}
# ../datasets/celeb10AdvancedWithProfilePhotosOnly\test\ Zoe Kravitz\zoepro.jpg
# Total Remaining : 10
# Binary Search till 2
# Average scores: {' Chloe Sevigny': np.float32(0.5870567), ' David Harbour': np.float32(0.26576814), ' Emma Chamberlain': np.float32(0.61156535), ' Florence Pugh': np.float32(0.65209657), ' Lily Rabe': np.float32(0.6581024), ' Penelope Cruz': np.float32(0.64225096), ' Sam Rockwell': np.float32(0.3621185), ' Tom Hollander': np.float32(0.24104694), ' Vincent Cassel': np.float32(0.2566908), ' Zoe Kravitz': np.float32(0.68490386)}
# Total scores: {' Chloe Sevigny': 52, ' David Harbour': 21, ' Emma Chamberlain': 58, ' Florence Pugh': 79, ' Lily Rabe': 85, ' Penelope Cruz': 76, ' Sam Rockwell': 40, ' Tom Hollander': 15, ' Vincent Cassel': 24, ' Zoe Kravitz': 100}
# Accuracy using average score: 60.00%
# Accuracy using frequency score: 60.00%

# %% [markdown]
# #### **Testing**

# %%
from SimilarityCalculatorAdvancedCorrected2 import SimilarityCalculatorAdvancedCorrected2
from FaceNetModelAdvanced import FaceNetModelAdvanced
import pandas as pd

# Similarity calculation
face_net_model = FaceNetModelAdvanced()
dataset_dir = "../datasets/celeb10AdvancedWithProfilePhotosOnly"  # Path to your dataset folder
embeddings_dir = f"{dataset_dir}/embeddings"
similarity_calculator = SimilarityCalculatorAdvancedCorrected2(embeddings_dir)
test_image_path = "../test_image/zoepro.jpg"
similar_personality_by_average, similar_personality_by_total = similarity_calculator.calculate_similarity(test_image_path, face_net_model)

df = pd.DataFrame(similar_personality_by_average)
print(f"Most similar personality Avergae based: {similar_personality_by_average[0][0]} with similarity score: {similar_personality_by_average[0][1]}")
print(f"Most similar personality Total based: {similar_personality_by_total[0][0]} with similarity score: {similar_personality_by_total[0][1]}")

display(df)
# Out:
# InceptionResNetV1 model loaded successfully!
# ../test_image/zoepro.jpg
# Total Remaining : 10
# Binary Search till 2
# Round 10 scores: [(' Zoe Kravitz', np.float32(0.7616575)), (' Florence Pugh', np.float32(0.7260673)), (' Penelope Cruz', np.float32(0.7085264)), (' Chloe Sevigny', np.float32(0.7039729)), (' Lily Rabe', np.float32(0.69603515)), (' Emma Chamberlain', np.float32(0.68099487)), (' Sam Rockwell', np.float32(0.3911795)), (' Vincent Cassel', np.float32(0.3851468)), (' David Harbour', np.float32(0.34522343)), (' Tom Hollander', np.float32(0.31641597))]
# Round 10 scores: [(' Zoe Kravitz', np.float32(0.78665745)), (' Florence Pugh', np.float32(0.749584)), (' Penelope Cruz', np.float32(0.73483086)), (' Lily Rabe', np.float32(0.728499)), (' Chloe Sevigny', np.float32(0.70939195)), (' Emma Chamberlain', np.float32(0.70876163)), (' Sam Rockwell', np.float32(0.38663113)), (' David Harbour', np.float32(0.36481392)), (' Vincent Cassel', np.float32(0.3556409)), (' Tom Hollander', np.float32(0.30614328))]
# Round 10 scores: [(' Penelope Cruz', np.float32(0.61679906)), (' Florence Pugh', np.float32(0.61235315)), (' Zoe Kravitz', np.float32(0.5997725)), (' Chloe Sevigny', np.float32(0.56811184)), (' Lily Rabe', np.float32(0.56299764)), (' Emma Chamberlain', np.float32(0.5568413)), (' Sam Rockwell', np.float32(0.4140153)), (' Vincent Cassel', np.float32(0.222745)), (' Tom Hollander', np.float32(0.20533961)), (' David Harbour', np.float32(0.19810241))]
# Round 10 scores: [(' Penelope Cruz', np.float32(0.56016743)), (' Zoe Kravitz', np.float32(0.55988926)), (' Lily Rabe', np.float32(0.5423929)), (' Florence Pugh', np.float32(0.52200437)), (' Emma Chamberlain', np.float32(0.5209388)), (' Chloe Sevigny', np.float32(0.5117368)), (' Sam Rockwell', np.float32(0.33161455)), (' Vincent Cassel', np.float32(0.19119066)), (' Tom Hollander', np.float32(0.18156153)), (' David Harbour', np.float32(0.17997146))]
# Round 10 scores: [(' Zoe Kravitz', np.float32(0.546085)), (' Penelope Cruz', np.float32(0.54304075)), (' Lily Rabe', np.float32(0.54178077)), (' Florence Pugh', np.float32(0.5280023)), (' Emma Chamberlain', np.float32(0.49126232)), (' Chloe Sevigny', np.float32(0.46095842)), (' Sam Rockwell', np.float32(0.3545072)), (' Tom Hollander', np.float32(0.2337544)), (' Vincent Cassel', np.float32(0.1806531)), (' David Harbour', np.float32(0.17044997))]
# Round 10 scores: [(' Zoe Kravitz', np.float32(0.78842187)), (' Florence Pugh', np.float32(0.7717761)), (' Lily Rabe', np.float32(0.7620918)), (' Penelope Cruz', np.float32(0.741637)), (' Emma Chamberlain', np.float32(0.7344961)), (' Chloe Sevigny', np.float32(0.69583637)), (' Sam Rockwell', np.float32(0.44137585)), (' David Harbour', np.float32(0.42196238)), (' Vincent Cassel', np.float32(0.40839016)), (' Tom Hollander', np.float32(0.3488425))]
# Round 10 scores: [(' Lily Rabe', np.float32(0.6854265)), (' Florence Pugh', np.float32(0.6495202)), (' Zoe Kravitz', np.float32(0.634823)), (' Penelope Cruz', np.float32(0.6324898)), (' Emma Chamberlain', np.float32(0.61847275)), (' Chloe Sevigny', np.float32(0.5719631)), (' Sam Rockwell', np.float32(0.34258628)), (' David Harbour', np.float32(0.25797558)), (' Tom Hollander', np.float32(0.23461068)), (' Vincent Cassel', np.float32(0.22998643))]
# Round 10 scores: [(' Zoe Kravitz', np.float32(0.60076046)), (' Florence Pugh', np.float32(0.58997107)), (' Lily Rabe', np.float32(0.58226514)), (' Penelope Cruz', np.float32(0.56372464)), (' Emma Chamberlain', np.float32(0.543113)), (' Chloe Sevigny', np.float32(0.5233765)), (' Sam Rockwell', np.float32(0.39528567)), (' Tom Hollander', np.float32(0.26470488)), (' Vincent Cassel', np.float32(0.23433757)), (' David Harbour', np.float32(0.21749073))]
# Round 10 scores: [(' Lily Rabe', np.float32(0.72907084)), (' Zoe Kravitz', np.float32(0.72302175)), (' Florence Pugh', np.float32(0.71225446)), (' Emma Chamberlain', np.float32(0.6846347)), (' Penelope Cruz', np.float32(0.65701354)), (' Chloe Sevigny', np.float32(0.5936293)), (' Sam Rockwell', np.float32(0.41238034)), (' David Harbour', np.float32(0.34895164)), (' Vincent Cassel', np.float32(0.29872298)), (' Tom Hollander', np.float32(0.29432434))]
# Round 10 scores: [(' Zoe Kravitz', np.float32(0.7254051)), (' Lily Rabe', np.float32(0.7146066)), (' Florence Pugh', np.float32(0.70995635)), (' Penelope Cruz', np.float32(0.67124397)), (' Emma Chamberlain', np.float32(0.6589426)), (' Chloe Sevigny', np.float32(0.5935334)), (' Sam Rockwell', np.float32(0.35811436)), (' David Harbour', np.float32(0.29757982)), (' Vincent Cassel', np.float32(0.26544762)), (' Tom Hollander', np.float32(0.2550776))]
# Average scores: {' Chloe Sevigny': np.float32(0.5932511), ' David Harbour': np.float32(0.28025213), ' Emma Chamberlain': np.float32(0.61984575), ' Florence Pugh': np.float32(0.65714896), ' Lily Rabe': np.float32(0.65451664), ' Penelope Cruz': np.float32(0.6429473), ' Sam Rockwell': np.float32(0.38276902), ' Tom Hollander': np.float32(0.26407748), ' Vincent Cassel': np.float32(0.27722615), ' Zoe Kravitz': np.float32(0.6726493)}
# Total scores: {' Chloe Sevigny': 55, ' David Harbour': 21, ' Emma Chamberlain': 58, ' Florence Pugh': 84, ' Lily Rabe': 80, ' Penelope Cruz': 79, ' Sam Rockwell': 40, ' Tom Hollander': 17, ' Vincent Cassel': 22, ' Zoe Kravitz': 94}
# Most similar personality Avergae based:  Zoe Kravitz with similarity score: 0.6726493239402771
# Most similar personality Total based:  Zoe Kravitz with similarity score: 94
#                    0         1
# 0        Zoe Kravitz  0.672649
# 1      Florence Pugh  0.657149
# 2          Lily Rabe  0.654517
# 3      Penelope Cruz  0.642947
# 4   Emma Chamberlain  0.619846
# 5      Chloe Sevigny  0.593251
# 6       Sam Rockwell  0.382769
# 7      David Harbour  0.280252
# 8     Vincent Cassel  0.277226
# 9      Tom Hollander  0.264077
